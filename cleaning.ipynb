# %%
# !pip install textract
# Out:
# ...
#      |████████████████████████████████| 102kB 3.3MB/s
# ...
#      |████████████████████████████████| 51kB 5.6MB/s
# ...
#      |████████████████████████████████| 112kB 23.5MB/s
# ...
#      |████████████████████████████████| 8.9MB 17.6MB/s
# ...
#      |████████████████████████████████| 32.8MB 108kB/s
# ...
#      |████████████████████████████████| 5.6MB 24.8MB/s
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/ebooklib/
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/00/38/7d6ab2e569a9165249619d73b7bc6be0e713a899a3bc2513814b6598a84c/EbookLib-0.17.1.tar.gz
# ...
#      |████████████████████████████████| 112kB 2.7MB/s
# ...
#      |████████████████████████████████| 81kB 5.4MB/s
# ...

# %%
import os
import textract
import re
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#raw_text = ''
#for filename in os.listdir('/content/drive/Shared drives/test/canciones'):
#  print(filename)
#  raw_text += open('/content/drive/Shared drives/test/canciones/'+filename, 'r', encoding='utf-8').read()
#raw_text = raw_text.lower()
path = '/content/drive/Shared drives/test/'
text_file = open('/content/drive/Shared drives/test/allSongs.txt', "w")
for filename in os.listdir(path+'canciones'):
  print(filename)
  text = textract.process(path+'canciones/'+filename, )
  words = re.sub(r'[^a-zA-Z \n]+', '', text.lower().decode("utf-8") )
  print(words)
  text_file.write(words)
text_file.close()
# Out:
# adentro.txt
# s que mis rimas a veces causan disgusto
# cuando mis neuronas corren hasta yo mismo me asusto
# mis respuestas pueden ser tan agresivas
# que hasta las letras me huyen porque tienen miedo de que las escriba
# no tengo ries pa matarte solo basta con la pista
# convierto letras en ideas como un ilusionista
# en una lnea te mato te fracturo te lesiono
# y en la siguiente te resucito cuando te menciono
# eso es parte de mi arte que todo el mundo sepa
# que estas rimas son pa ti sin tener que mencionarte
# y no lo hago para evitar el roce
# lo hago pa no hacerte famoso en los pases donde nadie te conoce
# despus de ver como se mueven las guerras y las guerrillas
# tu crees que le voy a tener miedo a tu pandilla
# dispara cuando quiera raperito maleantoso
# aqu no gana el ms maleante gana el ms ingenioso
#
# en tu cabeza t eres un narco buscao por la polica
# y tus pistolas son como los unicornios de fantasa
# no hay problemas en que tengas enemigos imaginarios
# ...
